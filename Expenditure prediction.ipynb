------------+-------------------+
# only showing top 20 rows
#
# </div>

# %%
data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Email: string (nullable = true)
# -- Address: string (nullable = true)
# -- Avatar: string (nullable = true)
# -- Avg Session Length: double (nullable = true)
# -- Time on App: double (nullable = true)
# -- Time on Website: double (nullable = true)
# -- Length of Membership: double (nullable = true)
# -- Yearly Amount Spent: double (nullable = true)
#
# </div>

# %%
for item in data.head(1)[0]:
  print(item)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">mstephenson@fernandez.com
# 835 Frank TunnelWrightmouth, MI 82180-9605
# Violet
# 34.4972677251
# 12.6556511492
# 39.5776680195
# 4.08262063295
# 587.951053968
# </div>

# %%
#setup dataframe for machine learning
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>
# [&apos;Email&apos;,
#  &apos;Address&apos;,
#  &apos;Avatar&apos;,
#  &apos;Avg Session Length&apos;,
#  &apos;Time on App&apos;,
#  &apos;Time on Website&apos;,
#  &apos;Length of Membership&apos;,
#  &apos;Yearly Amount Spent&apos;]
# </div>

# %%
#convert numerical columns , categorical data will not work
assembler = VectorAssembler(inputCols=['Avg Session Length','Time on App','Time on Website','Length of Membership'],outputCol='features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output = assembler.transform(data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Email: string (nullable = true)
# -- Address: string (nullable = true)
# -- Avatar: string (nullable = true)
# -- Avg Session Length: double (nullable = true)
# -- Time on App: double (nullable = true)
# -- Time on Website: double (nullable = true)
# -- Length of Membership: double (nullable = true)
# -- Yearly Amount Spent: double (nullable = true)
# -- features: vector (nullable = true)
#
# </div>

# %%
output.head(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">18</span><span class="ansired">]: </span>[Row(Email=u&apos;mstephenson@fernandez.com&apos;, Address=u&apos;835 Frank TunnelWrightmouth, MI 82180-9605&apos;, Avatar=u&apos;Violet&apos;, Avg Session Length=34.49726772511229, Time on App=12.65565114916675, Time on Website=39.57766801952616, Length of Membership=4.0826206329529615, Yearly Amount Spent=587.9510539684005, features=DenseVector([34.4973, 12.6557, 39.5777, 4.0826]))]
# </div>

# %%
final_data = output.select('features','Yearly Amount Spent')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------------------+
#             features|Yearly Amount Spent|
# +--------------------+-------------------+
# [34.4972677251122...|  587.9510539684005|
# [31.9262720263601...|  392.2049334443264|
# [33.0009147556426...| 487.54750486747207|
# [34.3055566297555...|  581.8523440352177|
# [33.3306725236463...|  599.4060920457634|
# [33.8710378793419...|   637.102447915074|
# [32.0215955013870...|  521.5721747578274|
# [32.7391429383803...|  549.9041461052942|
# [33.9877728956856...|  570.2004089636196|
# [31.9365486184489...|  427.1993848953282|
# [33.9925727749537...|  492.6060127179966|
# [33.8793608248049...|  522.3374046069357|
# [29.5324289670579...|  408.6403510726275|
# [33.1903340437226...|  573.4158673313865|
# [32.3879758531538...|  470.4527333009554|
# [30.7377203726281...|  461.7807421962299|
# [32.1253868972878...| 457.84769594494855|
# [32.3388993230671...| 407.70454754954415|
# [32.1878120459321...|  452.3156754800354|
# [32.6178560628234...|   605.061038804892|
# +--------------------+-------------------+
# only showing top 20 rows
#
# </div>

# %%
train_data,test_data = final_data.randomSplit([0.7,0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_data.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------------+
# summary|Yearly Amount Spent|
# +-------+-------------------+
#   count|                348|
#    mean|  501.7767847723878|
#  stddev|  81.21184478840817|
#     min| 256.67058229005585|
#     max|  765.5184619388373|
# +-------+-------------------+
#
# </div>

# %%
test_data.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------------+
# summary|Yearly Amount Spent|
# +-------+-------------------+
#   count|                152|
#    mean|  493.6756449243722|
#  stddev|  74.74425575957537|
#     min| 298.76200786180766|
#     max|  700.9170916173961|
# +-------+-------------------+
#
# </div>

# %%
lr = LinearRegression(featuresCol='features',labelCol='Yearly Amount Spent',predictionCol='predictions')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lr_model = lr.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_results = lr_model.evaluate(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#residuals = difference between actual value and predicted value from the test data
test_results.residuals.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+
#           residuals|
# +-------------------+
#  -5.191557161552794|
#  11.671840955238622|
# 0.39043216878246767|
#   3.720814888955033|
#   5.005521573974306|
#   4.141071330535965|
# -1.1548579994818056|
#    18.0836264115963|
#   7.572665453007573|
#   7.606367374795525|
#   9.107631931813842|
# -5.8368549384469475|
# -13.305549120304931|
#   8.394209345038348|
# -17.006116157142287|
#   4.188896433157822|
#  5.9806004017392524|
#   17.43676310215909|
#  23.256263690954313|
#    17.4760673183024|
# +-------------------+
# only showing top 20 rows
#
# </div>

# %%
test_results.rootMeanSquaredError
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">31</span><span class="ansired">]: </span>10.792703192439967
# </div>

# %%
test_results.r2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">32</span><span class="ansired">]: </span>0.9790119802392939
# </div>

# %%
final_data.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------------+
# summary|Yearly Amount Spent|
# +-------+-------------------+
#   count|                500|
#    mean|  499.3140382585909|
#  stddev|   79.3147815497068|
#     min| 256.67058229005585|
#     max|  765.5184619388373|
# +-------+-------------------+
#
# </div>

# %%
#deploy model
# we only have features pertaining to the data but do not have data regarding the expenditure in a year
unlabeled_data = test_data.select('features')
unlabeled_data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
#             features|
# +--------------------+
# [31.0613251567161...|
# [31.1695067987115...|
# [31.2606468698795...|
# [31.3091926408918...|
# [31.3584771924370...|
# [31.3662121671876...|
# [31.5761319713222...|
# [31.6098395733896...|
# [31.6548096756927...|
# [31.8209982016720...|
# [31.8512531286083...|
# [31.8745516945853...|
# [31.9365486184489...|
# [31.9549038566348...|
# [31.9563005605233...|
# [32.0123007682454...|
# [32.0305497162129...|
# [32.0478146331398...|
# [32.0498393904573...|
# [32.0609143984100...|
# +--------------------+
# only showing top 20 rows
#
# </div>

# %%
predictions = lr_model.transform(unlabeled_data)
predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------------------+
#             features|       predictions|
# +--------------------+------------------+
# [31.0613251567161...| 492.7470152194544|
# [31.1695067987115...| 415.6846898470542|
# [31.2606468698795...| 420.9361990881689|
# [31.3091926408918...| 428.9999029509786|
# [31.3584771924370...| 490.1704288755011|
# [31.3662121671876...|426.44781122594895|
# [31.5761319713222...| 542.3814419888101|
# [31.6098395733896...|426.46192323951186|
# [31.6548096756927...|467.69075827454094|
# [31.8209982016720...| 417.0689136384178|
# [31.8512531286083...|463.88461473498455|
# [31.8745516945853...|398.12209918471444|
# [31.9365486184489...| 440.5049340156331|
# [31.9549038566348...| 431.6036705948886|
# [31.9563005605233...| 564.1320479043411|
# [32.0123007682454...| 488.7561566328004|
# [32.0305497162129...| 588.2938830168725|
# [32.0478146331398...| 479.9527946566843|
# [32.0498393904573...|  455.463093183261|
# [32.0609143984100...| 610.1272513947126|
# +--------------------+------------------+
# only showing top 20 rows
#
# </div>
